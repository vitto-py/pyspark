# %% [markdown]
# # Install JAVA
# must be version 17 or earlier, newer version are not suported
# <br>
# **Install Java**
# > dpkg -i jdk-from-oracle.deb

# %% [markdown]
# **Was successfully installed?**
# ```bash
# java -version
# java version 17
# .....
# ....
# ```
# Find where java lives using
# ```bash
# $ whereis java
# > /usr/bin/java #this directory is not the final one
# $ ls -l /usr/bin/java #follow the semilink until it does not point to other folder anymore
# ```
# |Follow the link|Add the path to the Env Variables|
# |---|---|
# |![image.png](attachment:image.png)|![image-2.png](attachment:image-2.png)|
#
#
# ```bash
# nano .bashrc # see how in the image JAVA_HOME is added and also the /bin to the path
# source .bashrc
# ```

# %% [markdown]
# # Confluent Kafka
# ---

# %% [markdown]
# |env variables|comment|
# |---|---|
# |![image.png](attachment:image.png)|add this env variables to the `.bashrc`file |
